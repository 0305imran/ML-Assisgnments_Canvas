# %% [markdown]
# # Assignment

# %% [markdown]
# ## Task 1.1
# #### Install Jupyter notebook and run the first program and share the screenshot of the output.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Task 1.2
# #### Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included).
# #### The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
Numbers = []

for FindNum in range(2000,3201):
    if (FindNum%7==0) and (FindNum%5!=0):
        Numbers.append(str(FindNum))

print(','.join(Numbers))
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199

# %% [markdown]
# ## Task1.3
# #### Write a Python program to accept the user's first and last name and then
# #### getting them printed in the the reverse order with a space between first name and last name.

# %%
FirstName = input("Please give your first name: ")
LastName = input("Please give your last name: ")

FullName = FirstName + " " + LastName

print("\n" + "Reverse ordered output----------------->", FullName[::-1])

print ("Another example with sequence reversed->", LastName + " " + FirstName)
# Out:
# Please give your first name: Imran
# Please give your last name: Ahmad
#
# Reverse ordered output-----------------> damhA narmI
# Another example with sequence reversed-> Ahmad Imran

# %% [markdown]
# ## Task 1.4
# #### Write a Python program to find the volume of a sphere with diameter 12 cm.
# #### Formula: V=4/3 * π * r 3

# %%
import math

Var_Diameter = 12

Var_Volume = 4/3*math.pi*math.pow((Var_Diameter/2),3)

print("Volume of the sphere = ", Var_Volume)
# Out:
# Volume of the sphere =  904.7786842338603

# %% [markdown]
# ## Task 2.1
# #### Write a program which accepts a sequence of comma-separated numbers from console and generate a list.

# %%
Var_Final_List = []
Var_input_string = input("Please enter a list numbers separated by commas: ")
Var_list = Var_input_string.split(",")

print("Final list generated: ", Var_list)
# Out:
# Please enter a list numbers separated by commas: 1,2,3,4,5,6
# Final list generated:  ['1', '2', '3', '4', '5', '6']

# %% [markdown]
# ## Task 2.2
# #### Create the below pattern using nested for loop in Python.

# %%
Var_Iterate = 1

for counter in range(1,6):
    print("*"*counter)

for counter in range(4,0,-1):
    print("*"*counter)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ## Task 2.3
# #### Write a Python program to reverse a word after accepting the input from the user.

# %%
Var_Input_Value = input("Please give your string: ")

print(Var_Input_Value[::-1])
# Out:
# Please give your string: You are a hero
# oreh a era uoY

# %% [markdown]
# ## Task 2.4
# #### ![image.png](attachment:image.png)

# %%
# Output using "\n" and \t"
# The "!" sign after should not be there in the output. I have kept it to keep it same as the above Sample Output.

print ("WE, THE PEOPLE OF INDIA, " + "\n" + "\t" + "having solemnly resolved to constitute India into a SOVEREIGN,!" + "\n" + "\t\t" + "SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC" + "\n" + "\t\t" +" and to secure to all its citizens")
# Out:
# WE, THE PEOPLE OF INDIA,
# 	having solemnly resolved to constitute India into a SOVEREIGN, !
# 		SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
# 		 and to secure to all its citizens

# %%
# Output using "\n" and " "
# The "!" sign after should not be there in the output. I have kept it to keep it same as the above Sample Output.

print ("WE, THE PEOPLE OF INDIA, " + "\n" + "      " + "having solemnly resolved to constitute India into a SOVEREIGN,!" + "\n" + "      "+ "       " + "SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC" + "\n" + "      "+ "       "  +" and to secure to all its citizens")
# Out:
# WE, THE PEOPLE OF INDIA,
#       having solemnly resolved to constitute India into a SOVEREIGN,!
#              SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
#               and to secure to all its citizens
